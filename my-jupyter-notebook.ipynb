# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **My name is Ivan**
#
# I am a philosopher interested in techy stuff.

# %% [markdown]
# *I am interested in data science because I have seen the benefits of incorporating datadriven solutions to an array of social and political issues that interest me.

# %% [markdown]
# ### The code below multiplies a given number by 10.

# %%
def mult_ten(n):
    return 10*n

mult_ten(150)
# Out:
# 1500

# %% [markdown]
# ***
# I like doing lists because:
#  - You can write about anything. As Aristotle said
#  > One cannot argue with plants!
#  - You can prioritize:
#     1. Urgent things
#     2. Important things
#     3. Things that can wait
#  - You can write about websites that interest you like __[Coursera](https://www.coursera.org/)__
